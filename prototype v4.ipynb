# %%
import requests
import json
import csv
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
global API_key
import random
from tkinter import ttk
from tkinter import *
from tkinter.ttk import *

API_key = 'AIzaSyC3KEcQ1eTQl8v3O3ktO2U5Jj_BaftdJ1I'

# %%
csv_file = open("books.csv", "w", newline="", encoding="utf-8")
csv_writer = csv.writer(csv_file)
csv_writer.writerow(["title", "author", "genre", "description", "rating", "page count"])
# Out:
# 50

# %%
#putting API info into a csv file
class Genres:
    def __init__(self,genre):
        self.genre = genre
        
    def get_info(self):
        link = requests.get(f"https://www.googleapis.com/books/v1/volumes?q=subject:{self.genre}&maxResults=40&key={API_key}")
           
        json = link.json()
        
        info = json['items']
        
        
        for i in info:
            
            try:
                title = i['volumeInfo']['title']
                authors = i['volumeInfo']['authors']
                gen = self.genre
                description = i['volumeInfo']['description']
                rating = i['volumeInfo']['averageRating']
                pages = i['volumeInfo']['pageCount']
                
            except:
                description = "No description"
                rating = 0
                pages = 0
            
            
            csv_writer.writerow([title, authors, gen, description, rating, pages])

# %%
#getting the info from genres in the csv
def get_genres():
    mystery = Genres('mystery')
    mystery.get_info()
    
    romance = Genres('romance')
    romance.get_info()
    
    fantasy = Genres('fantasy')
    fantasy.get_info()
    
    fiction = Genres('fiction')
    fiction.get_info()
    
    scifi = Genres('science fiction')
    scifi.get_info()
    
    dystopian = Genres('dystopian')
    dystopian.get_info()
    
    thriller = Genres('thriller')
    thriller.get_info()
    
    drama = Genres('drama')
    drama.get_info()
    
    horror = Genres('horror')
    horror.get_info()
    
get_genres()

# %%
df = pd.read_csv("books.csv")
global df
df
# Out:
#                                      title  \
# 0                        The Invisible Man
# 1                  Where are the Children?
# 2                                Deja Dead
# 3                         "A" is for Alibi
# 4                    A Murder is Announced
# ..                                     ...
# 345       The Ocean at the End of the Lane
# 346                            Firestarter
# 347  Frankenstein Or the Modern Prometheus
# 348                               The M.D.
# 349                         The Green Mile
#
#                                      author    genre  \
# 0    ['Len Jenkin', 'Herbert George Wells']  mystery
# 1                    ['Mary Higgins Clark']  mystery
# 2                          ['Kathy Reichs']  mystery
# 3                           ['Sue Grafton']  mystery
# 4                       ['Agatha Christie']  mystery
# ..                                      ...      ...
# 345                         ['Neil Gaiman']   horror
# 346                        ['Stephen King']   horror
# 347         ['Mary Wollstonecraft Shelley']   horror
# 348                     ['Thomas M. Disch']   horror
# 349                        ['Stephen King']   horror
#
#                                            description  rating  page count
# 0                                       No description     0.0           0
# 1    A mother is accused in the gruesome deaths of ...     3.5         232
# 2    "Fans of TV's CSI: Crime Scene Investigation s...     4.0         422
# 3    Laurence Fife was a slick divorce lawyer and s...     3.5         294
# 4    A childish practical joke? Or a hoax intended ...     3.5         244
# ..                                                 ...     ...         ...
# 345                                     No description     0.0           0
# 346  From the author of THE SHINING, CARRIE and THE...     3.5         510
# 347                                     No description     0.0           0
# 348  A huge, mesmeric, tantalizing novel of suspens...     3.5         424
# 349  The Green Mile: those who walk it do not retur...     4.0         453
#
# [350 rows x 6 columns]

# %%
def convert_dtypes(): #doing this so ratings and page count can be operated on later with the filter
    df['rating'] = df['rating'].astype(float)
    df['page count'] = df['page count'].astype(int)
    
def removeBrackets():
    df['author'] = df['author'].apply(lambda x: x.replace('[','').replace(']','').replace("'",""))
    #https://stackoverflow.com/questions/38147447/how-to-remove-square-bracket-from-pandas-dataframe
        
convert_dtypes()
removeBrackets()

# %%
df
# Out:
#                                      title                            author  \
# 0                        The Invisible Man  Len Jenkin, Herbert George Wells
# 1                  Where are the Children?                Mary Higgins Clark
# 2                                Deja Dead                      Kathy Reichs
# 3                         "A" is for Alibi                       Sue Grafton
# 4                    A Murder is Announced                   Agatha Christie
# ..                                     ...                               ...
# 345       The Ocean at the End of the Lane                       Neil Gaiman
# 346                            Firestarter                      Stephen King
# 347  Frankenstein Or the Modern Prometheus       Mary Wollstonecraft Shelley
# 348                               The M.D.                   Thomas M. Disch
# 349                         The Green Mile                      Stephen King
#
#        genre                                        description  rating  \
# 0    mystery                                     No description     0.0
# 1    mystery  A mother is accused in the gruesome deaths of ...     3.5
# 2    mystery  "Fans of TV's CSI: Crime Scene Investigation s...     4.0
# 3    mystery  Laurence Fife was a slick divorce lawyer and s...     3.5
# 4    mystery  A childish practical joke? Or a hoax intended ...     3.5
# ..       ...                                                ...     ...
# 345   horror                                     No description     0.0
# 346   horror  From the author of THE SHINING, CARRIE and THE...     3.5
# 347   horror                                     No description     0.0
# 348   horror  A huge, mesmeric, tantalizing novel of suspens...     3.5
# 349   horror  The Green Mile: those who walk it do not retur...     4.0
#
#      page count
# 0             0
# 1           232
# 2           422
# 3           294
# 4           244
# ..          ...
# 345           0
# 346         510
# 347           0
# 348         424
# 349         453
#
# [350 rows x 6 columns]

# %%
df.dtypes
# Out:
# title           object
# author          object
# genre           object
# description     object
# rating         float64
# page count       int64
# dtype: object

# %% [markdown]
# ---------------------------------------------------------------

# %%
#this cell handles all the behind the scenes code

root = Tk()
root.title=('Book Recommender')
root.geometry = ('10000x10000')
    
#https://stackoverflow.com/questions/14824163/how-to-get-the-input-from-the-tkinter-text-widget - this helped a lot

global user_genre
global user_rating
global user_pages 

global genrebox
global ratingbox
global pagesbox

global genre_filter
global df2


def execute():
    #creating text and entry box displays
    ask_genre = Label(root, text=f"What genre do you prefer?", font=('Arial',15))
    ask_rating = Label(root, text= f"Would you like to filter by rating? If yes, enter the lowest rating you would like to see? (ratings range from 1.0-5.0). If no, enter N: ", font=('Arial',15))
    ask_pages = Label(root, text=f"Would you like to filter by page count? If yes, enter your ideal max page count. If no, enter N: ", font=('Arial',15))
    
    global genre_list
    genre_list = ['','mystery','romance','fantasy','fiction','science fiction','dystopian','thriller','drama','horror']
    
    global genre_value
    genre_value = StringVar()
    genre_value.set("Select a Genre")
    
    global rating_value
    rating_value = StringVar()
    rating_value.set('')
    
    global pages_value
    pages_value = IntVar()
    pages_value.set('')
    
    genrebox = OptionMenu(root, value, *genre_list)
    ratingbox = Text(root, height = 3, width = 10)
    pagesbox = Text(root, height = 3, width = 10)     
    
    ask_genre.grid(row = 1, pady=10)
    genrebox.grid(row = 2, pady=10)

    ask_rating.grid(row = 3, pady=10)
    ratingbox.grid(row = 4, pady=10)
    
    ask_pages.grid(row = 5, pady=10)
    pagesbox.grid(row = 6, pady=10)

    #this function will actually do all the filtering
    def get_results():
        genre_filter = df
        df2 = genre_filter
        
        user_genre = genre_value.get()
        user_rating = ratingbox.get('1.0','end-1c')
        user_pages = pagesbox.get('1.0','end-1c')
        
        for i in df['genre']:
            if user_genre.lower() == i:
                genre_filter = (df[df['genre']==user_genre])
                df2 = genre_filter
            
        if user_rating!='N':
            preferred_rating = float(user_rating)
            for row in genre_filter: #https://www.freecodecamp.org/news/drop-list-of-rows-from-pandas-dataframe/
                df2.drop(df2[(df2['rating'] < float(preferred_rating))].index, inplace=True) #if rating is below the user's preference, it is dropped from the df
        elif user_rating=='N':
            pass

        if user_pages.lower()!='n':
            preferred_page_count = int(user_pages)
            for row in genre_filter: 
                df2.drop(df2[(df2['page count'] > preferred_page_count)].index, inplace=True)
        elif user_pages=='N':
            pass
                
        #create final df with filtered results, https://stackoverflow.com/questions/57829917/how-to-display-pandas-dataframe-properly-using-tkinter
        global df3
        df3 = df2.sample(n=3)
    
        print(df3)
        
        cols = list(df3.columns)
        tree = Treeview(root) #Treeview is what displays the df3 results
        tree.grid(row = 10)
        tree["columns"] = cols
        for i in cols:
            tree.column(i, anchor="w")
            tree.heading(i, text=i, anchor='w')
        tree.column(0, width=10)
        tree.column('title', width=150)
        tree.column('author', width=150)
        tree.column('genre', width=100)
        tree.column('description', width=500)
        tree.column('rating',width=50)
        tree.column('page count', width=65)

        for index, row in df3.iterrows():
            tree.insert("",0,text=index,values=list(row))

    buttonCommit=Button(root, width=20, text="Confirm/Refresh Results", 
                    command=get_results)
    buttonCommit.grid(row=11)
    
    #randomized book recommendation
    ask_random = Label(root, text=f"Feeling adventurous? Click this button to get a random book recommendation", font=('Arial',15))
    ask_random.grid(row=12,pady=10)
    
    def randomOption():
        random_df = df.sample(n=1)
        print(random_df)
        
        cols = list(random_df.columns)
        tree = Treeview(root)
        tree.grid(row = 14)
        tree["columns"] = cols
        for i in cols:
            tree.column(i, anchor="w")
            tree.heading(i, text=i, anchor='w')
        tree.column(0, width=10)
        tree.column('title', width=150)
        tree.column('author', width=150)
        tree.column('genre', width=100)
        tree.column('description', width=500)
        tree.column('rating',width=50)
        tree.column('page count', width=65)

        for index, row in random_df.iterrows():
            tree.insert("",0,text=index,values=list(row))
        
    buttonRandom = Button(root, width=40,text=f"Random/Refresh",command=randomOption)
    buttonRandom.grid(row=13,  pady=15)

    root.mainloop()
                        
execute()
# Out:
#                      title         author     genre  \
# 252              Sandstorm  James Rollins  thriller
# 113                   Page  Tamora Pierce   fantasy
# 63   Sense and Sensibility    Jane Austen   romance
#
#                                            description  rating  page count
# 252  Twenty years after a wealthy British financier...     4.0         375
# 113                                     Fantasy-roman.     4.0         284
# 63   Classics with legible texts you can actually r...     4.5           0
#                    title           author    genre  \
# 112  The Thief of Always     Clive Barker  fantasy
# 38          To the Nines  Janet Evanovich  mystery
# 339  Unnatural Creatures      Neil Gaiman   horror
#
#                                            description  rating  page count
# 112  After a mysterious stranger promises to end hi...     4.0         292
# 38   Pursuing a skip, Stephanie travels to Las Vega...     4.0         360
# 339  The griffin, the sunbird, manticores, unicorns...     4.0         481
#              title         author            genre  \
# 71            Emma    Jane Austen          romance
# 167  Time Machines  Paul J. Nahin  science fiction
# 131   Bag of Bones   Stephen King          fiction
#
#                                            description  rating  page count
# 71   Classics with legible texts you can actually r...     4.0         512
# 167  This book explores the idea of time travel fro...     4.5         674
# 131  From #1 New York Times bestselling author Step...     4.5         756
#            title        author    genre  \
# 121  There There  Tommy Orange  fiction
#
#                                            description  rating  page count
# 121  NATIONAL BESTSELLER • PEN/HEMINGWAY AWARD WINN...     4.0         304
# 1   HIToolbox                           0x00007ff82166a726 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 102
# 2   HIToolbox                           0x00007ff82166a2b8 _ZN15MenuBarInstance14EnableAutoShowEv + 52
# 3   HIToolbox                           0x00007ff8215d9cd7 _ZN15MenuBarInstance21UpdateAggregateUIModeE21MenuBarAnimationStylehhh + 1113
# 4   HIToolbox                           0x00007ff82166a173 _ZN15MenuBarInstance19SetFullScreenUIModeEjj + 175
# 5   AppKit                              0x00007ff81ab314b7 -[NSApplication _setPresentationOptions:instance:flags:] + 1145
# 6   AppKit                              0x00007ff81a986165 -[NSApplication _updateFullScreenPresentationOptionsForInstance:] + 582
# 7   CoreFoundation                      0x00007ff8177656d6 __CFNOTIFICATIONCENTER_IS_CALLING_OUT_TO_AN_OBSERVER__ + 137
# 8   CoreFoundation                      0x00007ff8177fecbc ___CFXRegistrationPost_block_invoke + 86
# 9   CoreFoundation                      0x00007ff8177fec13 _CFXRegistrationPost + 534
# 10  CoreFoundation                      0x00007ff817738e31 _CFXNotificationPost + 809
# 11  Foundation                          0x00007ff8184adf2c -[NSNotificationCenter postNotificationName:object:userInfo:] + 82
# 12  AppKit                              0x00007ff81ab31b28 spacesNotificationHandler + 119
# 13  SkyLight                            0x00007ff81c2cf74d _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 1030
# 14  SkyLight                            0x00007ff81c5e204a _ZN21CGSDatagramReadStream26dispatchMainQueueDatagramsEv + 202
# 15  SkyLight                            0x00007ff81c5e1f71 ___ZN21CGSDatagramReadStream15mainQueueWakeupEv_block_invoke + 18
# 16  libdispatch.dylib                   0x00007ff8175147fb _dispatch_call_block_and_release + 12
# 17  libdispatch.dylib                   0x00007ff817515a44 _dispatch_client_callout + 8
# 18  libdispatch.dylib                   0x00007ff8175227b9 _dispatch_main_queue_drain + 952
# 19  libdispatch.dylib                   0x00007ff8175223f3 _dispatch_main_queue_callback_4CF + 31
# 20  CoreFoundation                      0x00007ff8177ae43d __CFRUNLOOP_IS_SERVICING_THE_MAIN_DISPATCH_QUEUE__ + 9
# 21  CoreFoundation                      0x00007ff81776eecb __CFRunLoopRun + 2498
# 22  CoreFoundation                      0x00007ff81776de8f CFRunLoopRunSpecific + 560
# 23  libtcl8.6.dylib                     0x000000012ef29944 Tcl_WaitForEvent + 308
# 24  libtcl8.6.dylib                     0x000000012eed2cdf Tcl_DoOneEvent + 319
# 25  _tkinter.cpython-39-darwin.so       0x00000001149fa664 _tkinter_tkapp_mainloop_impl + 228
# 26  python3.9                           0x0000000102f41d59 method_vectorcall_FASTCALL + 105
# 27  python3.9                           0x0000000103060e5e call_function + 174
# 28  python3.9                           0x00000001030588fa _PyEval_EvalFrameDefault + 22570
# 29  python3.9                           0x0000000103051a09 _PyEval_EvalCode + 489
# 30  python3.9                           0x0000000102f33b0c _PyFunction_Vectorcall + 236
# 31  python3.9                           0x0000000102f36e2e method_vectorcall + 158
# 32  python3.9                           0x0000000103060e5e call_function + 174
# 33  python3.9                           0x0000000103059c51 _PyEval_EvalFrameDefault + 27521
# 34  python3.9                           0x0000000103051a09 _PyEval_EvalCode + 489
# 35  python3.9                           0x0000000102f33b0c _PyFunction_Vectorcall + 236
# 36  python3.9                           0x0000000103060e5e call_function + 174
# 37  python3.9                           0x0000000103058f3d _PyEval_EvalFrameDefault + 24173
# 38  python3.9                           0x0000000103051a09 _PyEval_EvalCode + 489
# 39  python3.9                           0x000000010304bf09 builtin_exec + 377
# 40  python3.9                           0x0000000102f8f755 cfunction_vectorcall_FASTCALL + 85
# 41  python3.9                           0x0000000103060e5e call_function + 174
# 42  python3.9                           0x0000000103058f3d _PyEval_EvalFrameDefault + 24173
# 43  python3.9                           0x0000000102f4cccf gen_send_ex + 175
# 44  python3.9                           0x000000010305b013 _PyEval_EvalFrameDefault + 32579
# 45  python3.9                           0x0000000102f4cccf gen_send_ex + 175
# 46  python3.9                           0x000000010305b013 _PyEval_EvalFrameDefault + 32579
# 47  python3.9                           0x0000000102f4cccf gen_send_ex + 175
# 48  python3.9                           0x0000000102f41967 method_vectorcall_O + 103
# 49  python3.9                           0x0000000103060e5e call_function + 174
# 50  python3.9                           0x00000001030588fa _PyEval_EvalFrameDefault + 22570
# 51  python3.9                           0x0000000102f33bcb function_code_fastcall + 139
# 52  python3.9                           0x0000000103060e5e call_function + 174
# 53  python3.9                           0x0000000103058f3d _PyEval_EvalFrameDefault + 24173
# 54  python3.9                           0x0000000102f33bcb function_code_fastcall + 139
# 55  python3.9                           0x0000000103060e5e call_function + 174
# 56  python3.9                           0x00000001030588fa _PyEval_EvalFrameDefault + 22570
# 57  python3.9                           0x0000000103051a09 _PyEval_EvalCode + 489
# 58  python3.9                           0x0000000102f33b0c _PyFunction_Vectorcall + 236
# 59  python3.9                           0x0000000102f36e2e method_vectorcall + 158
# 60  python3.9                           0x0000000102f33783 PyVectorcall_Call + 163
# 61  python3.9                           0x00000001030587d6 _PyEval_EvalFrameDefault + 22278
# 62  python3.9                           0x0000000103051a09 _PyEval_EvalCode + 489
# 63  python3.9                           0x0000000102f33b0c _PyFunction_Vectorcall + 236
# 64  python3.9                           0x0000000102f36e2e method_vectorcall + 158
# 65  python3.9                           0x0000000103060e5e call_function + 174
# 66  python3.9                           0x0000000103054252 _PyEval_EvalFrameDefault + 4482
# 67  python3.9                           0x0000000102f4cccf gen_send_ex + 175
# 68  python3.9                           0x000000010305b013 _PyEval_EvalFrameDefault + 32579
# 69  python3.9                           0x0000000102f4cccf gen_send_ex + 175
# 70  python3.9                           0x000000010305b013 _PyEval_EvalFrameDefault + 32579
# 71  python3.9                           0x0000000102f4cccf gen_send_ex + 175
# 72  python3.9                           0x000000010305b013 _PyEval_EvalFrameDefault + 32579
# 73  python3.9                           0x0000000102f4cccf gen_send_ex + 175
# 74  python3.9                           0x000000010305b013 _PyEval_EvalFrameDefault + 32579
# 75  python3.9                           0x0000000102f4cccf gen_send_ex + 175
# 76  _asyncio.cpython-39-darwin.so       0x000000010c76b97a task_step_impl + 442
# 77  _asyncio.cpython-39-darwin.so       0x000000010c76b72e task_step + 62
# 78  _asyncio.cpython-39-darwin.so       0x000000010c76b5c8 task_wakeup + 104
# 79  _asyncio.cpython-39-darwin.so       0x000000010c76b4bd TaskWakeupMethWrapper_call + 109
# 80  python3.9                           0x0000000102f32e86 _PyObject_MakeTpCall + 134
# 81  python3.9                           0x000000010307c641 context_run + 81
# 82  python3.9                           0x0000000102f8f68c cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 83  python3.9                           0x00000001030587d6 _PyEval_EvalFrameDefault + 22278
# 84  python3.9                           0x0000000102f33bcb function_code_fastcall + 139
# 85  python3.9                           0x0000000103060e5e call_function + 174
# 86  python3.9                           0x00000001030588fa _PyEval_EvalFrameDefault + 22570
# 87  python3.9                           0x0000000102f33bcb function_code_fastcall + 139
# 88  python3.9                           0x0000000103060e5e call_function + 174
# 89  python3.9                           0x00000001030588fa _PyEval_EvalFrameDefault + 22570
# 90  python3.9                           0x0000000102f33bcb function_code_fastcall + 139
# 91  python3.9                           0x0000000103060e5e call_function + 174
# 92  python3.9                           0x00000001030588fa _PyEval_EvalFrameDefault + 22570
# 93  python3.9                           0x0000000102f33bcb function_code_fastcall + 139
# 94  python3.9                           0x0000000103060e5e call_function + 174
# 95  python3.9                           0x00000001030588fa _PyEval_EvalFrameDefault + 22570
# 96  python3.9                           0x0000000102f33bcb function_code_fastcall + 139
# 97  python3.9                           0x0000000103060e5e call_function + 174
# 98  python3.9                           0x00000001030588fa _PyEval_EvalFrameDefault + 22570
# 99  python3.9                           0x0000000103051a09 _PyEval_EvalCode + 489
# 100 python3.9                           0x0000000102f33b0c _PyFunction_Vectorcall + 236
# 101 python3.9                           0x0000000102f36e2e method_vectorcall + 158
# 102 python3.9                           0x0000000103060e5e call_function + 174
# 103 python3.9                           0x0000000103059c51 _PyEval_EvalFrameDefault + 27521
# 104 python3.9                           0x0000000103051a09 _PyEval_EvalCode + 489
# 105 python3.9                           0x000000010304bf09 builtin_exec + 377
# 106 python3.9                           0x0000000102f8f755 cfunction_vectorcall_FASTCALL + 85
# 107 python3.9                           0x0000000103060e5e call_function + 174
# 108 python3.9                           0x0000000103058f3d _PyEval_EvalFrameDefault + 24173
# 109 python3.9                           0x0000000103051a09 _PyEval_EvalCode + 489
# 110 python3.9                           0x0000000102f33b0c _PyFunction_Vectorcall + 236
# 111 python3.9                           0x0000000103060e5e call_function + 174
# 112 python3.9                           0x0000000103058f3d _PyEval_EvalFrameDefault + 24173
# 113 python3.9                           0x0000000103051a09 _PyEval_EvalCode + 489
# 114 python3.9                           0x0000000102f33b0c _PyFunction_Vectorcall + 236
# 115 python3.9                           0x00000001030e5142 pymain_run_module + 258
# 116 python3.9                           0x00000001030e4a01 pymain_run_python + 241
# 117 python3.9                           0x00000001030e48c5 Py_RunMain + 37
# 118 python3.9                           0x00000001030e5f90 pymain_main + 64
# 119 python3.9                           0x0000000102eca408 main + 56
# 120 dyld                                0x0000000203619310 start + 2432
# 1   HIToolbox                           0x00007ff8215f70c2 _ZN15MenuBarInstance22RemoveAutoShowObserverEv + 30
# 2   HIToolbox                           0x00007ff821633638 _ZL17BroadcastInternaljPvh + 167
# 3   SkyLight                            0x00007ff81c2cf74d _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 1030
# 4   SkyLight                            0x00007ff81c5e204a _ZN21CGSDatagramReadStream26dispatchMainQueueDatagramsEv + 202
# 5   SkyLight                            0x00007ff81c5e1f71 ___ZN21CGSDatagramReadStream15mainQueueWakeupEv_block_invoke + 18
# 6   libdispatch.dylib                   0x00007ff8175147fb _dispatch_call_block_and_release + 12
# 7   libdispatch.dylib                   0x00007ff817515a44 _dispatch_client_callout + 8
# 8   libdispatch.dylib                   0x00007ff8175227b9 _dispatch_main_queue_drain + 952
# 9   libdispatch.dylib                   0x00007ff8175223f3 _dispatch_main_queue_callback_4CF + 31
# 10  CoreFoundation                      0x00007ff8177ae43d __CFRUNLOOP_IS_SERVICING_THE_MAIN_DISPATCH_QUEUE__ + 9
# 11  CoreFoundation                      0x00007ff81776eecb __CFRunLoopRun + 2498
# 12  CoreFoundation                      0x00007ff81776de8f CFRunLoopRunSpecific + 560
# 13  libtcl8.6.dylib                     0x000000012ef29944 Tcl_WaitForEvent + 308
# 14  libtcl8.6.dylib                     0x000000012eed2cdf Tcl_DoOneEvent + 319
# 15  _tkinter.cpython-39-darwin.so       0x00000001149fa664 _tkinter_tkapp_mainloop_impl + 228
# 16  python3.9                           0x0000000102f41d59 method_vectorcall_FASTCALL + 105
# 17  python3.9                           0x0000000103060e5e call_function + 174
# 18  python3.9                           0x00000001030588fa _PyEval_EvalFrameDefault + 22570
# 19  python3.9                           0x0000000103051a09 _PyEval_EvalCode + 489
# 20  python3.9                           0x0000000102f33b0c _PyFunction_Vectorcall + 236
# 21  python3.9                           0x0000000102f36e2e method_vectorcall + 158
# 22  python3.9                           0x0000000103060e5e call_function + 174
# 23  python3.9                           0x0000000103059c51 _PyEval_EvalFrameDefault + 27521
# 24  python3.9                           0x0000000103051a09 _PyEval_EvalCode + 489
# 25  python3.9                           0x0000000102f33b0c _PyFunction_Vectorcall + 236
# 26  python3.9                           0x0000000103060e5e call_function + 174
# 27  python3.9                           0x0000000103058f3d _PyEval_EvalFrameDefault + 24173
# 28  python3.9                           0x0000000103051a09 _PyEval_EvalCode + 489
# 29  python3.9                           0x000000010304bf09 builtin_exec + 377
# 30  python3.9                           0x0000000102f8f755 cfunction_vectorcall_FASTCALL + 85
# 31  python3.9                           0x0000000103060e5e call_function + 174
# 32  python3.9                           0x0000000103058f3d _PyEval_EvalFrameDefault + 24173
# 33  python3.9                           0x0000000102f4cccf gen_send_ex + 175
# 34  python3.9                           0x000000010305b013 _PyEval_EvalFrameDefault + 32579
# 35  python3.9                           0x0000000102f4cccf gen_send_ex + 175
# 36  python3.9                           0x000000010305b013 _PyEval_EvalFrameDefault + 32579
# 37  python3.9                           0x0000000102f4cccf gen_send_ex + 175
# 38  python3.9                           0x0000000102f41967 method_vectorcall_O + 103
# 39  python3.9                           0x0000000103060e5e call_function + 174
# 40  python3.9                           0x00000001030588fa _PyEval_EvalFrameDefault + 22570
# 41  python3.9                           0x0000000102f33bcb function_code_fastcall + 139
# 42  python3.9                           0x0000000103060e5e call_function + 174
# 43  python3.9                           0x0000000103058f3d _PyEval_EvalFrameDefault + 24173
# 44  python3.9                           0x0000000102f33bcb function_code_fastcall + 139
# 45  python3.9                           0x0000000103060e5e call_function + 174
# 46  python3.9                           0x00000001030588fa _PyEval_EvalFrameDefault + 22570
# 47  python3.9                           0x0000000103051a09 _PyEval_EvalCode + 489
# 48  python3.9                           0x0000000102f33b0c _PyFunction_Vectorcall + 236
# 49  python3.9                           0x0000000102f36e2e method_vectorcall + 158
# 50  python3.9                           0x0000000102f33783 PyVectorcall_Call + 163
# 51  python3.9                           0x00000001030587d6 _PyEval_EvalFrameDefault + 22278
# 52  python3.9                           0x0000000103051a09 _PyEval_EvalCode + 489
# 53  python3.9                           0x0000000102f33b0c _PyFunction_Vectorcall + 236
# 54  python3.9                           0x0000000102f36e2e method_vectorcall + 158
# 55  python3.9                           0x0000000103060e5e call_function + 174
# 56  python3.9                           0x0000000103054252 _PyEval_EvalFrameDefault + 4482
# 57  python3.9                           0x0000000102f4cccf gen_send_ex + 175
# 58  python3.9                           0x000000010305b013 _PyEval_EvalFrameDefault + 32579
# 59  python3.9                           0x0000000102f4cccf gen_send_ex + 175
# 60  python3.9                           0x000000010305b013 _PyEval_EvalFrameDefault + 32579
# 61  python3.9                           0x0000000102f4cccf gen_send_ex + 175
# 62  python3.9                           0x000000010305b013 _PyEval_EvalFrameDefault + 32579
# 63  python3.9                           0x0000000102f4cccf gen_send_ex + 175
# 64  python3.9                           0x000000010305b013 _PyEval_EvalFrameDefault + 32579
# 65  python3.9                           0x0000000102f4cccf gen_send_ex + 175
# 66  _asyncio.cpython-39-darwin.so       0x000000010c76b97a task_step_impl + 442
# 67  _asyncio.cpython-39-darwin.so       0x000000010c76b72e task_step + 62
# 68  _asyncio.cpython-39-darwin.so       0x000000010c76b5c8 task_wakeup + 104
# 69  _asyncio.cpython-39-darwin.so       0x000000010c76b4bd TaskWakeupMethWrapper_call + 109
# 70  python3.9                           0x0000000102f32e86 _PyObject_MakeTpCall + 134
# 71  python3.9                           0x000000010307c641 context_run + 81
# 72  python3.9                           0x0000000102f8f68c cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 73  python3.9                           0x00000001030587d6 _PyEval_EvalFrameDefault + 22278
# 74  python3.9                           0x0000000102f33bcb function_code_fastcall + 139
# 75  python3.9                           0x0000000103060e5e call_function + 174
# 76  python3.9                           0x00000001030588fa _PyEval_EvalFrameDefault + 22570
# 77  python3.9                           0x0000000102f33bcb function_code_fastcall + 139
# 78  python3.9                           0x0000000103060e5e call_function + 174
# 79  python3.9                           0x00000001030588fa _PyEval_EvalFrameDefault + 22570
# 80  python3.9                           0x0000000102f33bcb function_code_fastcall + 139
# 81  python3.9                           0x0000000103060e5e call_function + 174
# 82  python3.9                           0x00000001030588fa _PyEval_EvalFrameDefault + 22570
# 83  python3.9                           0x0000000102f33bcb function_code_fastcall + 139
# 84  python3.9                           0x0000000103060e5e call_function + 174
# 85  python3.9                           0x00000001030588fa _PyEval_EvalFrameDefault + 22570
# 86  python3.9                           0x0000000102f33bcb function_code_fastcall + 139
# 87  python3.9                           0x0000000103060e5e call_function + 174
# 88  python3.9                           0x00000001030588fa _PyEval_EvalFrameDefault + 22570
# 89  python3.9                           0x0000000103051a09 _PyEval_EvalCode + 489
# 90  python3.9                           0x0000000102f33b0c _PyFunction_Vectorcall + 236
# 91  python3.9                           0x0000000102f36e2e method_vectorcall + 158
# 92  python3.9                           0x0000000103060e5e call_function + 174
# 93  python3.9                           0x0000000103059c51 _PyEval_EvalFrameDefault + 27521
# 94  python3.9                           0x0000000103051a09 _PyEval_EvalCode + 489
# 95  python3.9                           0x000000010304bf09 builtin_exec + 377
# 96  python3.9                           0x0000000102f8f755 cfunction_vectorcall_FASTCALL + 85
# 97  python3.9                           0x0000000103060e5e call_function + 174
# 98  python3.9                           0x0000000103058f3d _PyEval_EvalFrameDefault + 24173
# 99  python3.9                           0x0000000103051a09 _PyEval_EvalCode + 489
# 100 python3.9                           0x0000000102f33b0c _PyFunction_Vectorcall + 236
# 101 python3.9                           0x0000000103060e5e call_function + 174
# 102 python3.9                           0x0000000103058f3d _PyEval_EvalFrameDefault + 24173
# 103 python3.9                           0x0000000103051a09 _PyEval_EvalCode + 489
# 104 python3.9                           0x0000000102f33b0c _PyFunction_Vectorcall + 236
# 105 python3.9                           0x00000001030e5142 pymain_run_module + 258
# 106 python3.9                           0x00000001030e4a01 pymain_run_python + 241
# 107 python3.9                           0x00000001030e48c5 Py_RunMain + 37
# 108 python3.9                           0x00000001030e5f90 pymain_main + 64
# 109 python3.9                           0x0000000102eca408 main + 56
# 110 dyld                                0x0000000203619310 start + 2432

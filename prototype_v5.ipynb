# %% [markdown]
# https://github.com/colavid1/book-recommender

# %%
import requests
import json
import csv
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
global API_key
import random
import tkinter as tk
from tkinter import ttk
from tkinter import *
from tkinter.ttk import *

API_key = 'AIzaSyC3KEcQ1eTQl8v3O3ktO2U5Jj_BaftdJ1I'

# %%
csv_file = open("books.csv", "w", newline="", encoding="utf-8")
csv_writer = csv.writer(csv_file)
csv_writer.writerow(["title", "author", "genre", "description", "rating", "page count"])
# Out:
# 50

# %%
#putting API info into a csv file
class Genres:
    def __init__(self,genre):
        self.genre = genre
        
    def get_info(self):
        link = requests.get(f"https://www.googleapis.com/books/v1/volumes?q=subject:{self.genre}&maxResults=40&key={API_key}")
           
        json = link.json()
        
        info = json['items']
        
        
        for i in info:
            
            try:
                title = i['volumeInfo']['title']
                authors = i['volumeInfo']['authors']
                gen = self.genre
                description = i['volumeInfo']['description']
                rating = i['volumeInfo']['averageRating']
                pages = i['volumeInfo']['pageCount']
                
            except:
                description = "No description"
                rating = 0
                pages = 0
            
            
            csv_writer.writerow([title, authors, gen, description, rating, pages])

# %%
#getting the info from genres in the csv
def get_genres():
    mystery = Genres('mystery')
    mystery.get_info()
    
    romance = Genres('romance')
    romance.get_info()
    
    fantasy = Genres('fantasy')
    fantasy.get_info()
    
    fiction = Genres('fiction')
    fiction.get_info()
    
    scifi = Genres('science fiction')
    scifi.get_info()
    
    dystopian = Genres('dystopian')
    dystopian.get_info()
    
    thriller = Genres('thriller')
    thriller.get_info()
    
    drama = Genres('drama')
    drama.get_info()
    
    horror = Genres('horror')
    horror.get_info()
    
get_genres()

# %%
df = pd.read_csv("books.csv")
global df
df
# Out:
#                                      title  \
# 0                        The Invisible Man
# 1                  Where are the Children?
# 2                         "A" is for Alibi
# 3                       Tyrannosaur Canyon
# 4                                Deja Dead
# ..                                     ...
# 346                                 Spiral
# 347  Frankenstein Or the Modern Prometheus
# 348                          The Dead Zone
# 349                        The Empty House
# 350                   All Our Hidden Gifts
#
#                                      author    genre  \
# 0    ['Len Jenkin', 'Herbert George Wells']  mystery
# 1                    ['Mary Higgins Clark']  mystery
# 2                           ['Sue Grafton']  mystery
# 3                       ['Douglas Preston']  mystery
# 4                          ['Kathy Reichs']  mystery
# ..                                      ...      ...
# 346        ['Kōji Suzuki', 'Glynne Walley']   horror
# 347         ['Mary Wollstonecraft Shelley']   horror
# 348         ['Mary Wollstonecraft Shelley']   horror
# 349                  ['Algernon Blackwood']   horror
# 350                 ["Caroline O'Donoghue"]   horror
#
#                                            description  rating  page count
# 0                                       No description     0.0           0
# 1    A mother is accused in the gruesome deaths of ...     3.5         302
# 2    Laurence Fife was a slick divorce lawyer and s...     3.5         294
# 3    A moon rock missing for thirty years... Five b...     3.5         382
# 4    "Fans of TV's CSI: Crime Scene Investigation s...     4.0         422
# ..                                                 ...     ...         ...
# 346  Learning about a series of mysterious deaths c...     2.5         283
# 347                                     No description     0.0           0
# 348                                     No description     0.0           0
# 349  Ten horror stories. For contents, see Author C...     4.0         360
# 350  Maeve Chambers doesn't have much going for her...     4.0         385
#
# [351 rows x 6 columns]

# %%
def convert_dtypes(): #doing this so ratings and page count can be operated on later with the filter
    df['rating'] = df['rating'].astype(float)
    df['page count'] = df['page count'].astype(int)
    
def removeBrackets():
    df['author'] = df['author'].apply(lambda x: x.replace('[','').replace(']','').replace("'",""))
    #https://stackoverflow.com/questions/38147447/how-to-remove-square-bracket-from-pandas-dataframe
        
convert_dtypes()
removeBrackets()

# %%
df
# Out:
#                                      title                            author  \
# 0                        The Invisible Man  Len Jenkin, Herbert George Wells
# 1                  Where are the Children?                Mary Higgins Clark
# 2                         "A" is for Alibi                       Sue Grafton
# 3                       Tyrannosaur Canyon                   Douglas Preston
# 4                                Deja Dead                      Kathy Reichs
# ..                                     ...                               ...
# 346                                 Spiral        Kōji Suzuki, Glynne Walley
# 347  Frankenstein Or the Modern Prometheus       Mary Wollstonecraft Shelley
# 348                          The Dead Zone       Mary Wollstonecraft Shelley
# 349                        The Empty House                Algernon Blackwood
# 350                   All Our Hidden Gifts              "Caroline ODonoghue"
#
#        genre                                        description  rating  \
# 0    mystery                                     No description     0.0
# 1    mystery  A mother is accused in the gruesome deaths of ...     3.5
# 2    mystery  Laurence Fife was a slick divorce lawyer and s...     3.5
# 3    mystery  A moon rock missing for thirty years... Five b...     3.5
# 4    mystery  "Fans of TV's CSI: Crime Scene Investigation s...     4.0
# ..       ...                                                ...     ...
# 346   horror  Learning about a series of mysterious deaths c...     2.5
# 347   horror                                     No description     0.0
# 348   horror                                     No description     0.0
# 349   horror  Ten horror stories. For contents, see Author C...     4.0
# 350   horror  Maeve Chambers doesn't have much going for her...     4.0
#
#      page count
# 0             0
# 1           302
# 2           294
# 3           382
# 4           422
# ..          ...
# 346         283
# 347           0
# 348           0
# 349         360
# 350         385
#
# [351 rows x 6 columns]

# %%
df.dtypes
# Out:
# title           object
# author          object
# genre           object
# description     object
# rating         float64
# page count       int64
# dtype: object

# %% [markdown]
# ---------------------------------------------------------------

# %%
#this cell handles all the behind the scenes code

root = Tk()
root.title('Book Recommender')
root.geometry = ('10000x10000')
root.config(bg="pink")

    
#https://stackoverflow.com/questions/14824163/how-to-get-the-input-from-the-tkinter-text-widget - this helped a lot

global user_genre
global user_rating
global user_pages 

global genrebox
global ratingbox
global pagesbox

global genre_filter
global df2


def execute():
    #creating text and entry box displays
    ask_genre = tk.Label(root, text=f"What genre do you prefer?", bg='pink',font=('Comic Sans MS',15))
    ask_rating = tk.Label(root, text= f"Would you like to filter by rating? If yes, enter the lowest rating you would like to see? (ratings range from 1.0-5.0). If no, enter N: ", bg='pink', font=('Comic Sans MS',15))
    ask_pages = tk.Label(root, text=f"Would you like to filter by page count? If yes, enter your ideal max page count. If no, enter N: ", bg='pink', font=('Comic Sans MS',15))
    
    global genre_list
    genre_list = ['','mystery','romance','fantasy','fiction','science fiction','dystopian','thriller','drama','horror']
    
    global genre_value
    genre_value = StringVar()
    genre_value.set("Select a Genre")
    
    global rating_value
    rating_value = StringVar()
    rating_value.set('')
    
    global pages_value
    pages_value = IntVar()
    pages_value.set('')
    
    genrebox = OptionMenu(root, genre_value, *genre_list)
    ratingbox = tk.Text(root, height = 3, width = 10, bg='mistyrose')
    pagesbox = Text(root, height = 3, width = 10, bg='mistyrose')     
    
    ask_genre.grid(row = 1, pady=10)
    genrebox.grid(row = 2, pady=10)

    ask_rating.grid(row = 3, pady=10)
    ratingbox.grid(row = 4, pady=10)
    
    ask_pages.grid(row = 5, pady=10)
    pagesbox.grid(row = 6, pady=10)

    #this function will actually do all the filtering
    def get_results():
        genre_filter = df
        df2 = genre_filter
        
        user_genre = genre_value.get()
        user_rating = ratingbox.get('1.0','end-1c')
        user_pages = pagesbox.get('1.0','end-1c')
        
        for i in df['genre']:
            if user_genre.lower() == i:
                genre_filter = (df[df['genre']==user_genre])
                df2 = genre_filter
            
        if user_rating!='N':
            preferred_rating = float(user_rating)
            for row in genre_filter: #https://www.freecodecamp.org/news/drop-list-of-rows-from-pandas-dataframe/
                df2.drop(df2[(df2['rating'] < float(preferred_rating))].index, inplace=True) #if rating is below the user's preference, it is dropped from the df
        elif user_rating=='N':
            pass

        if user_pages.lower()!='n':
            preferred_page_count = int(user_pages)
            for row in genre_filter: 
                df2.drop(df2[(df2['page count'] > preferred_page_count)].index, inplace=True)
        elif user_pages=='N':
            pass
                
        #create final df with filtered results, https://stackoverflow.com/questions/57829917/how-to-display-pandas-dataframe-properly-using-tkinter
        global df3
        df3 = df2.sample(n=3)
    
        print(df3)
        
        cols = list(df3.columns)
        tree = Treeview(root) #Treeview is what displays the df3 results
        tree.grid(row = 10)
        tree["columns"] = cols
        for i in cols:
            tree.column(i, anchor="w")
            tree.heading(i, text=i, anchor='w')
        tree.column(0, width=10)
        tree.column('title', width=150)
        tree.column('author', width=150)
        tree.column('genre', width=100)
        tree.column('description', width=500)
        tree.column('rating',width=50)
        tree.column('page count', width=65)

        for index, row in df3.iterrows():
            tree.insert("",0,text=index,values=list(row))

    buttonCommit=tk.Button(root, width=20, text="Confirm/Refresh Results", fg='palevioletred', cursor="heart",
                    command=get_results)
    buttonCommit.grid(row=11)
    
    #randomized book recommendation
    ask_random = tk.Label(root, text=f"Feeling adventurous? Click this button to get a random book recommendation:", bg='pink', font=('Comic Sans MS',15))
    ask_random.grid(row=12,pady=10)
    
    def randomOption():
        random_df = df.sample(n=1)
        print(random_df)
        
        cols = list(random_df.columns)
        tree = Treeview(root)
        tree.grid(row = 14)
        tree["columns"] = cols
        for i in cols:
            tree.column(i, anchor="w")
            tree.heading(i, text=i, anchor='w')
        tree.column(0, width=10)
        tree.column('title', width=150)
        tree.column('author', width=150)
        tree.column('genre', width=100)
        tree.column('description', width=500)
        tree.column('rating',width=50)
        tree.column('page count', width=65)

        for index, row in random_df.iterrows():
            tree.insert("",0,text=index,values=list(row))
        
    buttonRandom = tk.Button(root, width=40,text=f"Random/Refresh",  fg='palevioletred', cursor="heart", command=randomOption)
    buttonRandom.grid(row=13, pady=15)

    root.mainloop()
                        
execute()
# Out:
#                       title              author    genre  \
# 31                 Cry Wolf        Wilbur Smith  mystery
# 28     The Road to Gandolfo       Robert Ludlum  mystery
# 1   Where are the Children?  Mary Higgins Clark  mystery
#
#                                           description  rating  page count
# 31  In 1935, Jake Barton, a tough engineer from Te...     4.0         484
# 28  A humourous tale where the premis is to kidnap...     3.5         322
# 1   A mother is accused in the gruesome deaths of ...     3.5         302
#            title                          author    genre  \
# 53  Simple Gifts  Judith McNaught, Jude Deveraux  romance
#
#                           description  rating  page count
# 53  4 Heartwarming Christmas Stories.     3.5         406

# %%
import requests
import json
import csv
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
global API_key
import random
from tkinter import ttk
from tkinter import *
from tkinter.ttk import *

API_key = 'AIzaSyC3KEcQ1eTQl8v3O3ktO2U5Jj_BaftdJ1I'

# %%
csv_file = open("books.csv", "w", newline="", encoding="utf-8")
csv_writer = csv.writer(csv_file)
csv_writer.writerow(["title", "author", "genre", "description", "category", "rating", "maturity rating", "page count"])
# Out:
# 75

# %%
class Genres:
    def __init__(self,genre):
        self.genre = genre
        
    def get_info(self):
        link = requests.get(f"https://www.googleapis.com/books/v1/volumes?q=subject:{self.genre}&maxResults=40&key={API_key}")
           
        json = link.json()
        
        info = json['items']
        
        
        for i in info:
            
            try:
                title = i['volumeInfo']['title']
                authors = i['volumeInfo']['authors']
                gen = self.genre
                description = i['volumeInfo']['description']
                category = i['volumeInfo']['categories']
                rating = i['volumeInfo']['averageRating']
                maturity = i['volumeInfo']['maturityRating']
                pages = i['volumeInfo']['pageCount']
                
            except:
                category = "Not specified"
                description = "No description"
                rating = 0
                maturity = "Not rated"
                pages = "No data"
            
            
            csv_writer.writerow([title, authors, gen, description, category, rating, maturity, pages])

# %%
def get_genres():
    mystery = Genres('mystery')
    mystery.get_info()
    
    romance = Genres('romance')
    romance.get_info()
    
    fantasy = Genres('fantasy')
    fantasy.get_info()
    
    fiction = Genres('fiction')
    fiction.get_info()
    
    scifi = Genres('science fiction')
    scifi.get_info()
    
    dystopian = Genres('dystopian')
    dystopian.get_info()
    
    thriller = Genres('thriller')
    thriller.get_info()
    
    drama = Genres('drama')
    drama.get_info()
    
    horror = Genres('horror')
    horror.get_info()
    
get_genres()

# %%
df = pd.read_csv("books.csv")
global df
df
# Out:
#                                title                                  author  \
# 0                  The Invisible Man  ['Len Jenkin', 'Herbert George Wells']
# 1            Where are the Children?                  ['Mary Higgins Clark']
# 2                          Deja Dead                        ['Kathy Reichs']
# 3                   "A" is for Alibi                         ['Sue Grafton']
# 4              A Murder is Announced                     ['Agatha Christie']
# ..                               ...                                     ...
# 336  Witcher Volume 3 Curse of Crows                          ['Paul Tobin']
# 337                         The Keep                      ['F. Paul Wilson']
# 338                             Cell                        ['Stephen King']
# 339              Unnatural Creatures                         ['Neil Gaiman']
# 340                           Spiral        ['Kōji Suzuki', 'Glynne Walley']
#
# ...

# %%
def convert_float(): #doing this so it ratings can be operated on later with the filter
    df['rating'] = df.rating.astype(float)
        
convert_float()

# %%
def get_results():
    return df2[['title','author','rating','description','page count','maturity rating']].sample(n=3) # randomly sample 3 rows from 

get_results()

# %%
def random_option():
    ask_random = input('Feeling adventurous? Would you like a random book suggestion? Y/N: ')
    if ask_random.lower()== 'y':
        return df[['title','author','genre','rating','description','page count','maturity rating']].sample(n=1)
random_option()

# %% [markdown]
# ---------------------------------------------------------------

# %%
#this cell handles all the behind the scenes code
root = Tk()
root.title=('Book Recommender')
root.geometry = ('1000x1000')
    
#https://stackoverflow.com/questions/14824163/how-to-get-the-input-from-the-tkinter-text-widget

global user_genre
global user_rating
global user_maturity
global user_pages 

global genrebox
global ratingbox
global maturitybox
global pagesbox

global genre_filter
global df2

def execute():
    ask_genre = Label(root, text=f"What genre do you prefer?", font=('Arial',15))
    ask_rating = Label(root, text= f"Would you like to filter by rating? If yes, enter the lowest rating you would like to see? (ratings range from 1.0-5.0). If no, enter 0.0: ", font=('Arial',15))
    ask_maturity = Label(root, text=f"Would you like to filter by maturity rating? If yes, enter Y. If no, enter N: ", font=('Arial',15))
    ask_pages = Label(root, text=f"Would you like to filter by page count? If yes, enter your ideal max page count. If no, enter N: ", font=('Arial',15))
    
    genrebox = Text(root, height = 2, width = 10)
    ratingbox = Text(root, height = 3, width = 10)
    ratingbox.insert(END,'0.0')
    maturitybox = Text(root, height = 3,width = 10)
    pagesbox = Text(root, height = 3, width = 10)     
    
    ask_genre.grid(row = 1, pady=10)
    genrebox.grid(row = 2, pady=10)

    ask_rating.grid(row = 3, pady=10)
    ratingbox.grid(row = 4, pady=10)

    ask_maturity.grid(row = 5, pady=10)
    maturitybox.grid(row = 6, pady=10)

    ask_pages.grid(row = 7, pady=10)
    pagesbox.grid(row = 8, pady=10)

  
    def get_results():
        genre_filter=df
        df2 = genre_filter
        
        user_genre = genrebox.get('1.0','end-1c')
        user_rating = float(ratingbox.get('1.0','end-1c'))
        user_maturity = maturitybox.get('1.0','end-1c')
        user_pages = pagesbox.get('1.0','end-1c')
        
        for i in df['genre']:
            if user_genre == i:
                genre_filter = (df[df['genre']==user_genre])
                df2 = genre_filter
            
        if ask_rating.lower()!=0.0:
            preferred_rating = float(user_rating)
            for row in genre_filter: #https://www.freecodecamp.org/news/drop-list-of-rows-from-pandas-dataframe/
                df2.drop(df2[(df2['rating'] < preferred_rating)].index, inplace=True) #if rating is below the user's preference, it is dropped from the df

        if ask_maturity.lower()!='n':
            preferred_maturity = user_maturity
            if preferred_maturity.lower()=='y':
                for row in genre_filter:
                    df2.drop(df2[(df2['maturity rating'] == "NOT_MATURE")].index, inplace=True)
        
        if ask_pages.lower()!='n':
            preferred_page_count = user_pages
            for row in genre_filter: 
                df2.drop(df2[(df2['page count'] > preferred_page_count)].index, inplace=True)
                
        #create final df with filtered results, https://stackoverflow.com/questions/57829917/how-to-display-pandas-dataframe-properly-using-tkinter
        global df3
        df3 = df2.sample(n=3)
    
        print(df3)
        
        cols = list(df3.columns)
        tree = Treeview(root)
        tree.grid(row = 10)
        tree["columns"] = cols
        for i in cols:
            tree.column(i, anchor="w")
            tree.heading(i, text=i, anchor='w')
        tree.column(0, width=10)
        tree.column('title', width=150)
        tree.column('author', width=150)
        tree.column('genre', width=100)
        tree.column('category',width=100)
        tree.column('rating',width=50)
        tree.column('maturity rating', width=100)
        tree.column('page count', width=65)

        for index, row in df3.iterrows():
            tree.insert("",0,text=index,values=list(row))

    buttonCommit=Button(root, width=20, text="Confirm", 
                    command=get_results)
    buttonCommit.grid(row=11)
    
    ask_random = Label(root, text=f"Feeling adventurous? Click this button to get a random book recommendation", font=('Arial',15))
    ask_random.grid(row=12,pady=10)
    
    def randomOption():
        random_df = df.sample(n=1)
        print(random_df)
        
        cols = list(random_df.columns)
        tree = Treeview(root)
        tree.grid(row = 14)
        tree["columns"] = cols
        for i in cols:
            tree.column(i, anchor="w")
            tree.heading(i, text=i, anchor='w')
        tree.column(0, width=10)
        tree.column('title', width=150)
        tree.column('author', width=150)
        tree.column('genre', width=100)
        tree.column('category',width=100)
        tree.column('rating',width=50)
        tree.column('maturity rating', width=100)
        tree.column('page count', width=65)

        for index, row in random_df.iterrows():
            tree.insert("",0,text=index,values=list(row))
        
    buttonRandom = Button(root, width=40,text=f"Get a random book",command=randomOption)
    buttonRandom.grid(row=13,  pady=15)

    root.mainloop()
                        
execute()
# Out:
# /var/folders/0v/thw4y_0n29j4rsjb5wx1jzbm0000gn/T/ipykernel_2263/851776161.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(df2[(df2['rating'] < preferred_rating)].index, inplace=True) #if rating is below the user's preference, it is dropped from the df
# /var/folders/0v/thw4y_0n29j4rsjb5wx1jzbm0000gn/T/ipykernel_2263/851776161.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(df2[(df2['page count'] > preferred_page_count)].index, inplace=True)
#                    title               author    genre  \
# 48        If Not for You  ['Debbie Macomber']  romance
# ...

# %%
       #https://stackoverflow.com/questions/71034460/display-csv-with-tkinter
        columns = ('title','author','rating','description','page count','maturity rating')
        for i, column in enumerate(columns, start=1):
            columns_label = Label(root, text=column).grid(row=10, column=i, padx=40)

        with open(df3, "r", newline="") as passfile:
            reader = csv.reader(passfile)
            data = list(reader)

        entrieslist = []
        for i, row in enumerate(data, start=4):
            entrieslist.append(row[0])
            for col in range(1, 8):
                table = Label(passScreen, text=row[col]).grid(row=i, column=col)

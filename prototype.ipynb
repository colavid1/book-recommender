# %%
import requests
import json
import csv
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
global API_key
import random
from tkinter import ttk
from tkinter import *
from tkinter.ttk import *

API_key = 'AIzaSyC3KEcQ1eTQl8v3O3ktO2U5Jj_BaftdJ1I'

# %%
csv_file = open("books.csv", "w", newline="", encoding="utf-8")
csv_writer = csv.writer(csv_file)
csv_writer.writerow(["title", "author", "genre", "description", "rating", "maturity rating", "page count"])
# Out:
# 66

# %%
#putting API info into a csv file
class Genres:
    def __init__(self,genre):
        self.genre = genre
        
    def get_info(self):
        link = requests.get(f"https://www.googleapis.com/books/v1/volumes?q=subject:{self.genre}&maxResults=40&key={API_key}")
           
        json = link.json()
        
        info = json['items']
        
        
        for i in info:
            
            try:
                title = i['volumeInfo']['title']
                authors = i['volumeInfo']['authors']
                gen = self.genre
                description = i['volumeInfo']['description']
                rating = i['volumeInfo']['averageRating']
                maturity = i['volumeInfo']['maturityRating']
                pages = i['volumeInfo']['pageCount']
                
            except:
                description = "No description"
                rating = 0
                maturity = "Not rated"
                pages = 0
            
            
            csv_writer.writerow([title, authors, gen, description, rating, maturity, pages])

# %%
#getting the info from genres in the csv
def get_genres():
    mystery = Genres('mystery')
    mystery.get_info()
    
    romance = Genres('romance')
    romance.get_info()
    
    fantasy = Genres('fantasy')
    fantasy.get_info()
    
    fiction = Genres('fiction')
    fiction.get_info()
    
    scifi = Genres('science fiction')
    scifi.get_info()
    
    dystopian = Genres('dystopian')
    dystopian.get_info()
    
    thriller = Genres('thriller')
    thriller.get_info()
    
    drama = Genres('drama')
    drama.get_info()
    
    horror = Genres('horror')
    horror.get_info()
    
get_genres()

# %%
df = pd.read_csv("books.csv")
global df
df
# Out:
#                                  title  \
# 0                    The Invisible Man
# 1              Where are the Children?
# 2                            Deja Dead
# 3                     "A" is for Alibi
# 4                A Murder is Announced
# ..                                 ...
# 351                          Cold Fire
# 352  The Dream-quest of Unknown Kadath
# 353    Pouvoirs de L'horreur (English)
# 354                  Different Seasons
# 355                        Forever Odd
#
#                                      author    genre  \
# 0    ['Len Jenkin', 'Herbert George Wells']  mystery
# 1                    ['Mary Higgins Clark']  mystery
# 2                          ['Kathy Reichs']  mystery
# 3                           ['Sue Grafton']  mystery
# 4                       ['Agatha Christie']  mystery
# ..                                      ...      ...
# 351                     ['Dean Ray Koontz']   horror
# 352           ['Howard Phillips Lovecraft']   horror
# 353                      ['Julia Kristeva']   horror
# 354                        ['Stephen King']   horror
# 355                     ['Dean Ray Koontz']   horror
#
#                                            description  rating  \
# 0                                       No description     0.0
# 1    A mother is accused in the gruesome deaths of ...     3.5
# 2    "Fans of TV's CSI: Crime Scene Investigation s...     4.0
# 3    Laurence Fife was a slick divorce lawyer and s...     3.5
# 4    A childish practical joke? Or a hoax intended ...     3.5
# ..                                                 ...     ...
# 351  Reporter Holly Thorne investigates the case of...     3.5
# 352  Six bone-chilling tales of bizarre beauty and ...     4.5
# 353                                              Essay     5.0
# 354  A Stephen King novel telling of unfair impriso...     4.0
# 355  In the unique world of Pico, Odd--an unforgett...     3.5
#
#     maturity rating  page count
# 0         Not rated           0
# 1        NOT_MATURE         232
# 2        NOT_MATURE         422
# 3        NOT_MATURE         294
# 4        NOT_MATURE         244
# ..              ...         ...
# 351      NOT_MATURE         382
# 352      NOT_MATURE         260
# 353      NOT_MATURE         236
# 354      NOT_MATURE         560
# 355      NOT_MATURE         364
#
# [356 rows x 7 columns]

# %%
def convert_dtypes(): #doing this so ratings and page count can be operated on later with the filter
    df['rating'] = df['rating'].astype(float)
    df['page count'] = df['page count'].astype(int)
    
def removeBrackets():
    df['author'] = df['author'].apply(lambda x: x.replace('[','').replace(']','').replace("'",""))
    #https://stackoverflow.com/questions/38147447/how-to-remove-square-bracket-from-pandas-dataframe
        
convert_dtypes()
removeBrackets()

# %%
df
# Out:
#                                  title                            author  \
# 0                    The Invisible Man  Len Jenkin, Herbert George Wells
# 1              Where are the Children?                Mary Higgins Clark
# 2                            Deja Dead                      Kathy Reichs
# 3                     "A" is for Alibi                       Sue Grafton
# 4                A Murder is Announced                   Agatha Christie
# ..                                 ...                               ...
# 351                          Cold Fire                   Dean Ray Koontz
# 352  The Dream-quest of Unknown Kadath         Howard Phillips Lovecraft
# 353    Pouvoirs de L'horreur (English)                    Julia Kristeva
# 354                  Different Seasons                      Stephen King
# 355                        Forever Odd                   Dean Ray Koontz
#
#        genre                                        description  rating  \
# 0    mystery                                     No description     0.0
# 1    mystery  A mother is accused in the gruesome deaths of ...     3.5
# 2    mystery  "Fans of TV's CSI: Crime Scene Investigation s...     4.0
# 3    mystery  Laurence Fife was a slick divorce lawyer and s...     3.5
# 4    mystery  A childish practical joke? Or a hoax intended ...     3.5
# ..       ...                                                ...     ...
# 351   horror  Reporter Holly Thorne investigates the case of...     3.5
# 352   horror  Six bone-chilling tales of bizarre beauty and ...     4.5
# 353   horror                                              Essay     5.0
# 354   horror  A Stephen King novel telling of unfair impriso...     4.0
# 355   horror  In the unique world of Pico, Odd--an unforgett...     3.5
#
#     maturity rating  page count
# 0         Not rated           0
# 1        NOT_MATURE         232
# 2        NOT_MATURE         422
# 3        NOT_MATURE         294
# 4        NOT_MATURE         244
# ..              ...         ...
# 351      NOT_MATURE         382
# 352      NOT_MATURE         260
# 353      NOT_MATURE         236
# 354      NOT_MATURE         560
# 355      NOT_MATURE         364
#
# [356 rows x 7 columns]

# %%
df.dtypes
# Out:
# title               object
# author              object
# genre               object
# description         object
# rating             float64
# maturity rating     object
# page count           int64
# dtype: object

# %% [markdown]
# ---------------------------------------------------------------

# %%
#this cell handles all the behind the scenes code

root = Tk()
root.title=('Book Recommender')
root.geometry = ('10000x10000')
    
#https://stackoverflow.com/questions/14824163/how-to-get-the-input-from-the-tkinter-text-widget - this helped a lot

global user_genre
global user_rating
global user_maturity
global user_pages 

global genrebox
global ratingbox
global maturitybox
global pagesbox

global genre_filter
global df2


def execute():
    #creating text and entry box displays
    ask_genre = Label(root, text=f"What genre do you prefer?", font=('Arial',15))
    ask_rating = Label(root, text= f"Would you like to filter by rating? If yes, enter the lowest rating you would like to see? (ratings range from 1.0-5.0). If no, enter N: ", font=('Arial',15))
    ask_maturity = Label(root, text=f"Would you like to filter by maturity rating? If yes, enter Y. If no, enter N: ", font=('Arial',15))
    ask_pages = Label(root, text=f"Would you like to filter by page count? If yes, enter your ideal max page count. If no, enter N: ", font=('Arial',15))
    
    global genre_list
    genre_list = ['','mystery','romance','fantasy','fiction','science fiction','dystopian','thriller','drama','horror']
    
    global value
    value = StringVar()
    value.set("Select a Genre")
    
    genrebox = OptionMenu(root, value, *genre_list)
    ratingbox = Text(root, height = 3, width = 10)
    maturitybox = Text(root, height = 3,width = 10)
    pagesbox = Text(root, height = 3, width = 10)     
    
    ask_genre.grid(row = 1, pady=10)
    genrebox.grid(row = 2, pady=10)

    ask_rating.grid(row = 3, pady=10)
    ratingbox.grid(row = 4, pady=10)

    ask_maturity.grid(row = 5, pady=10)
    maturitybox.grid(row = 6, pady=10)

    ask_pages.grid(row = 7, pady=10)
    pagesbox.grid(row = 8, pady=10)

    #this function will actually do all the filtering
    def get_results():
        genre_filter = df
        df2 = genre_filter
        
        user_genre = value.get()
        user_rating = ratingbox.get('1.0','end-1c')
        user_maturity = maturitybox.get('1.0','end-1c')
        user_pages = pagesbox.get('1.0','end-1c')
        
        for i in df['genre']:
            if user_genre.lower() == i:
                genre_filter = (df[df['genre']==user_genre])
                df2 = genre_filter
            
        if user_rating!='N':
            preferred_rating = float(user_rating)
            for row in genre_filter: #https://www.freecodecamp.org/news/drop-list-of-rows-from-pandas-dataframe/
                df2.drop(df2[(df2['rating'] < float(preferred_rating))].index, inplace=True) #if rating is below the user's preference, it is dropped from the df
        elif user_rating=='N':
            pass

        if user_maturity.lower()!='n':
            preferred_maturity = user_maturity
            if preferred_maturity.lower()=='y':
                for row in genre_filter:
                    df2.drop(df2[(df2['maturity rating'] == "NOT_MATURE")].index, inplace=True)
        
        if user_pages.lower()!='n':
            preferred_page_count = int(user_pages)
            for row in genre_filter: 
                df2.drop(df2[(df2['page count'] > preferred_page_count)].index, inplace=True)
        elif user_pages=='N':
            pass
                
        #create final df with filtered results, https://stackoverflow.com/questions/57829917/how-to-display-pandas-dataframe-properly-using-tkinter
        global df3
        df3 = df2.sample(n=3)
    
        print(df3)
        
        cols = list(df3.columns)
        tree = Treeview(root) #Treeview is what displays the df3 results
        tree.grid(row = 10)
        tree["columns"] = cols
        for i in cols:
            tree.column(i, anchor="w")
            tree.heading(i, text=i, anchor='w')
        tree.column(0, width=10)
        tree.column('title', width=150)
        tree.column('author', width=150)
        tree.column('genre', width=100)
        tree.column('description', width=400)
        tree.column('rating',width=50)
        tree.column('maturity rating', width=100)
        tree.column('page count', width=65)

        for index, row in df3.iterrows():
            tree.insert("",0,text=index,values=list(row))

    buttonCommit=Button(root, width=20, text="Confirm/Refresh Results", 
                    command=get_results)
    buttonCommit.grid(row=11)
    
    #randomized book recommendation
    ask_random = Label(root, text=f"Feeling adventurous? Click this button to get a random book recommendation", font=('Arial',15))
    ask_random.grid(row=12,pady=10)
    
    def randomOption():
        random_df = df.sample(n=1)
        print(random_df)
        
        cols = list(random_df.columns)
        tree = Treeview(root)
        tree.grid(row = 14)
        tree["columns"] = cols
        for i in cols:
            tree.column(i, anchor="w")
            tree.heading(i, text=i, anchor='w')
        tree.column(0, width=10)
        tree.column('title', width=150)
        tree.column('author', width=150)
        tree.column('genre', width=100)
        tree.column('description', width=400)
        tree.column('rating',width=50)
        tree.column('maturity rating', width=100)
        tree.column('page count', width=65)

        for index, row in random_df.iterrows():
            tree.insert("",0,text=index,values=list(row))
        
    buttonRandom = Button(root, width=40,text=f"Random/Refresh",command=randomOption)
    buttonRandom.grid(row=13,  pady=15)

    root.mainloop()
                        
execute()
# Out:
# /var/folders/0v/thw4y_0n29j4rsjb5wx1jzbm0000gn/T/ipykernel_2998/633303212.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(df2[(df2['rating'] < float(preferred_rating))].index, inplace=True) #if rating is below the user's preference, it is dropped from the df
# /var/folders/0v/thw4y_0n29j4rsjb5wx1jzbm0000gn/T/ipykernel_2998/633303212.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(df2[(df2['page count'] > preferred_page_count)].index, inplace=True)
#                        title           author    genre  \
# 13  And Then There Were None  Agatha Christie  mystery
# 10      The Road to Gandolfo    Robert Ludlum  mystery
# 38        The A.B.C. Murders  Agatha Christie  mystery
#
#                                           description  rating maturity rating  \
# 13  One by one, the guests arrived at the mansion ...     4.0      NOT_MATURE
# 10  A humourous tale where the premis is to kidnap...     3.5      NOT_MATURE
# 38  A is for Ascher, cudgeled in Andover. B is for...     3.5      NOT_MATURE
#
#     page count
# 13         294
# 10         312
# 38         252
